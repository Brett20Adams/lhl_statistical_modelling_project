# %%
# import the packages we will need for this project
import pandas as pd
import numpy as np
import json
import requests
import api_keys

# %%
stations_df = pd.read_csv('stations_df.csv')
FS_KEY = api_keys.FOURSQUARE
YELP_KEY = api_keys.YELP

# %% [markdown]
# # Foursquare

# %% [markdown]
# ## Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
def get_venues_fs(latitude, longitude, radius, categories):
    """
    Get venues from foursquare with a specified place type and coordinates.
    Args:
        latitude (float): latitude for query (must be combined with longitude)
        longitude (float): longitude for query (must be combined with latitude)
        api_key (str): foursquare API to use for query
        categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. Separate ids with commas
    
    Returns:
        response: response object from the requests library.
    """
    url = "https://api.foursquare.com/v3/places/search"
    
    params = {"categories": categories, # below, we will search for three different category types
              "radius":radius,
              "ll": f"{latitude},{longitude}",
              "limit":50, # this is the upper limit
              "fields": "rating,popularity"   # rating: A numerical rating (from 0.0 to 10.0) of the FSQ Place, based on user votes, likes/dislikes, tips sentiment, and visit data. Not all FSQ Places will have a rating.
                                              # popularity: A measure of the FSQ Place's popularity, by foot traffic. This score is on a 0 to 1 scale and uses a 6-month span of POI visits for a given geographic area.
             }
    # Create a dictionary for headers
    headers = {"Accept": "application/json"}
    # Add key with our API KEY
    headers['Authorization'] = FS_KEY 
    res = requests.get(url, params=params, headers=headers)
    foursquare_data = res.json()
    return foursquare_data

# %%
# test the function on bars (13003)
results = get_venues_fs(stations_df['latitude'][0], stations_df['longitude'][0], 1000, 13003)

# %% [markdown]
# ## Combine the above flow into a for loop to obtain a count of different venues for the dataset and their category ID's
# 1. Bars - 13003 (cocktail bars, pubs, sports bars etc.)
# 2. Lodging - 19009 (Hotels, Motels, Hostels etc.)
# 3. Transportation Hubs - 19030 (Train stations, bus stations, rental car locations etc.)

# %%
# create a function to count the results for each category returned by the API call
def category_count(category):
    """
    Loop through the stations_df dataframe and return a list of counts of the number of items returned in the get_venues_fs function that corresponds with the input category
    
    Args:
        category (integer): the category integer of what POI we are searching for

    Returns:
        response: count_of_category: a list of the number of POI's which match the category integer from the get_venues_fs function
    """
    count_of_category = []

    for row in stations_df.itertuples(index=False): 
        
        latitude = row[8] # store the latitude of each station in a variable
        longitude = row[9] # store the longitude of each station in a variable
        
        venue_results = get_venues_fs(latitude, longitude, 1000, category) # call the get_venues_fs function for each station 
        normalized_results = pd.json_normalize(venue_results['results']) # store and normalize the results
        
        count_of_results = len(normalized_results) # count the number of rows in the normalized results
        count_of_category.append(count_of_results) # append the count to the empty list
    return count_of_category

# %%
# create a function to calculate the average popularity for the response from each category returned by the get_venues_fs function
def popularity_average(category):
    """
    Loop through the stations_df dataframe and return the calculated average popularity from the items returned in the get_venues_fs function that corresponds with the input category and append that value to a list
    
    Args:
        category (integer): the category integer of what POI we are searching for

    Returns:
        response: average_category_popularity: a list of the average popularity of POI's which match the category integer from the get_venues_fs function
    """
    average_category_popularity = []

    for row in stations_df.itertuples(index=False): 
        latitude = row[8]
        longitude = row[9]
        
        venue_results = get_venues_fs(latitude, longitude, 1000, category)
        normalized_results = pd.json_normalize(venue_results['results'])
        
        # Check if the 'popularity' column exists in the normalized results
        if 'popularity' in normalized_results.columns:
            average_popularity = normalized_results['popularity'].mean()
            average_category_popularity.append(average_popularity)
        else:
            # Case when the 'popularity' column is missing
            average_category_popularity.append(0)
        
    return average_category_popularity

# %%
# create a function to calculate the average rating for the response from each category returned by the get_venues_fs function
def rating_average(category):
    """
    Loop through the stations_df dataframe and return the calculated average ratings from the items returned in the get_venues_fs function that corresponds with the input category and append that value to a list
    
    Args:
        category (integer): the category integer of what POI we are searching for

    Returns:
        response: average_category_rating: a list of the average ranking of POI's which match the category integer from the get_venues_fs function
    """
    average_category_rating = []

    for row in stations_df.itertuples(index=False): 
        latitude = row[8]
        longitude = row[9]
        
        venue_results = get_venues_fs(latitude, longitude, 1000, category)
        normalized_results = pd.json_normalize(venue_results['results'])
        
        # Check if the 'rating' column exists in the normalized results
        if 'rating' in normalized_results.columns:
            average_rating = normalized_results['rating'].mean()
            average_category_rating.append(average_rating)
        else:
            # Case when the 'rating' column is missing
            average_category_rating.append(0)
        
    return average_category_rating

# %% [markdown]
# ### Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# #### I will be appending the count of each POI type, as well as the average popularity and average rating if the POI has either of these metrics

# %% [markdown]
# ### Put your parsed results into a DataFrame

# %%
# run the functions for bars
stations_df['num_nearby_bars'] = category_count(13003)
stations_df['avg_pop_bars'] = popularity_average(13003)
stations_df['avg_rat_bars'] = rating_average(13003)

# %%
# run the functions for lodging
stations_df['num_nearby_lodging'] = category_count(19009)
stations_df['avg_pop_lodging'] = popularity_average(19009)
stations_df['avg_rat_lodging'] = rating_average(19009)

# %%
# run the functions for transportation hubs
stations_df['num_nearby_trans_hubs'] = category_count(19030)
stations_df['avg_pop_trans_hubs'] = popularity_average(19030)
stations_df['avg_rating_trans_hubs'] = rating_average(19030)

# %%
# save to dataframe
stations_df_fs = stations_df.to_csv('stations_df')

# %% [markdown]
# # Yelp

# %%
stations_df_fs = pd.read_csv('stations_df_fs.csv')

# %% [markdown]
# ## Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
def get_venues_yelp(latitude, longitude, radius, categories):
    """
    Get venues from YELP with a specified place type and coordinates.
    Args:
        latitude (float): latitude for query (must be combined with longitude)
        longitude (float): longitude for query (must be combined with latitude)
        api_key (str): foursquare API to use for query
        categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. Separate ids with commas
    
    Returns:
        response: response object from the requests library.
    """
    url = "https://api.yelp.com/v3/businesses/search"
    
    params = {"latitude": latitude, # below, we will search for three different category types
              "longitude": longitude,
              "limit": 50,
              "categories": categories 
             }
    # Create a dictionary for headers
    headers = {"Accept": "application/json"}
    # Add key with our API KEY
    headers['Authorization'] = f"Bearer {YELP_KEY}" 
    res = requests.get(url, params=params, headers=headers)
    yelp_data = res.json()
    return yelp_data

# %% [markdown]
# ### Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# ### Yelp Equivalents for Foursquare POI searches
# 1. Bars - 'bars' (Foursquare equivalent: 13003 (cocktail bars, pubs, sports bars etc.))
# 2. Hotels - 'hotels' (Foursquare equivalent: Lodging - 19009 (Hotels, Motels, Hostels etc.))
# 3. Transportation - 'transport' (Foursquare equivalent: Transportation Hubs - 19030 (Train stations, bus stations, rental car locations etc.))

# %%
# test with hotels
bars = get_venues_yelp(stations_df_fs['latitude'][0], stations_df_fs['longitude'][0], 1000, "hotels")
bars
# Out:
# {'businesses': [{'id': 'xJToH_Gy8RSKWqUPVUjwLw',
#    'alias': 'the-hoxton-downtown-los-angeles-6',
#    'name': 'The Hoxton - Downtown',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G9QprxDFATluEZ5pRoDtqg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-hoxton-downtown-los-angeles-6?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 156,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.039794135659584,
#     'longitude': -118.25856086441767},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1060 S Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1060 S Broadway', 'Los Angeles, CA 90015']},
#    'phone': '+12137255900',
#    'display_phone': '(213) 725-5900',
#    'distance': 2574.380646102008},
#   {'id': 'u6wFTRE9RUY_LGNnIDbrzQ',
#    'alias': 'omni-los-angeles-hotel-at-california-plaza-los-angeles-2',
#    'name': 'Omni Los Angeles Hotel at California Plaza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IWTBXO_pQjSPpvqMbiL66w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omni-los-angeles-hotel-at-california-plaza-los-angeles-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 774,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.052599008884606,
#     'longitude': -118.25050399999998},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '251 S Olive St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90012',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['251 S Olive St', 'Los Angeles, CA 90012']},
#    'phone': '+12136173300',
#    'display_phone': '(213) 617-3300',
#    'distance': 2656.0074429445453},
#   {'id': '1fGCTpM3zrcAgytrZA4mPQ',
#    'alias': 'los-angeles-athletic-club-hotel-los-angeles',
#    'name': 'Los Angeles Athletic Club Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5MAjrl28yo6Bn9cjN20nFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/los-angeles-athletic-club-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 101,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0466399, 'longitude': -118.25498},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '431 W 7th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['431 W 7th St', 'Los Angeles, CA 90014']},
#    'phone': '+12136252211',
#    'display_phone': '(213) 625-2211',
#    'distance': 2551.495763998917},
#   {'id': 'Nh3L9PtJZTSGhfeAxKO3Gg',
#    'alias': 'jw-marriott-los-angeles-l-a-live-los-angeles',
#    'name': 'JW Marriott Los Angeles L.A. LIVE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1IqBhbwNIQwBxfbWf4ndNw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jw-marriott-los-angeles-l-a-live-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 941,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.045237613517564,
#     'longitude': -118.26647042631456},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '900 West Olympic Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['900 West Olympic Blvd', 'Los Angeles, CA 90015']},
#    'phone': '+12137658600',
#    'display_phone': '(213) 765-8600',
#    'distance': 3443.9432035908103},
#   {'id': 'kvhmfXZ-JSkUUlsod_34OA',
#    'alias': 'ace-hotel-downtown-los-angeles-los-angeles',
#    'name': 'Ace Hotel Downtown Los Angeles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K4oavDTXOuh5OIPPvS_IFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ace-hotel-downtown-los-angeles-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 738,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.0417407368323,
#     'longitude': -118.25679388103},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '929 S Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['929 S Broadway', 'Los Angeles, CA 90015']},
#    'phone': '+12136233233',
#    'display_phone': '(213) 623-3233',
#    'distance': 2474.3685618190643},
#   {'id': '1PSkXp8N6-cczfIBijTgNA',
#    'alias': 'intercontinental-los-angeles-downtown-los-angeles-5',
#    'name': 'InterContinental Los Angeles Downtown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lSkSCLvo2KnfXUlwfY0Prg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/intercontinental-los-angeles-downtown-los-angeles-5?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 605,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.05014203645121,
#     'longitude': -118.26030027277535},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '900 Wilshire Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90017',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['900 Wilshire Blvd', 'Los Angeles, CA 90017']},
#    'phone': '+12136887777',
#    'display_phone': '(213) 688-7777',
#    'distance': 3171.7420261584384},
#   {'id': 'gO4UMDCi7g0r_oiq_cUq1g',
#    'alias': 'conrad-los-angeles-los-angeles',
#    'name': 'Conrad Los Angeles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-mwmV-gyz7R_A5AcFujjVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/conrad-los-angeles-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 86,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.05536, 'longitude': -118.24879},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '100 South Grand Ave.',
#     'address2': None,
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90012',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['100 South Grand Ave.', 'Los Angeles, CA 90012']},
#    'phone': '+12133498585',
#    'display_phone': '(213) 349-8585',
#    'distance': 2780.4664966562236},
#   {'id': 'hMoFC3fmCEN-bRAB_c_Ujw',
#    'alias': 'the-ritz-carlton-los-angeles-los-angeles-7',
#    'name': 'The Ritz Carlton Los Angeles',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kim_iHIyuI_AduJ0ZOFhdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ritz-carlton-los-angeles-los-angeles-7?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 290,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0452632224665,
#     'longitude': -118.266620451555},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '900 W Olympic Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['900 W Olympic Blvd', 'Los Angeles, CA 90015']},
#    'phone': '+12137438800',
#    'display_phone': '(213) 743-8800',
#    'distance': 3457.9178385755863},
#   {'id': 'Wh5ix84uh6MO5Rs1kI02gw',
#    'alias': 'the-line-la-los-angeles',
#    'name': 'The LINE LA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/g8e-yHS2naN-eFRqp-xYhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-line-la-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 1065,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.06213, 'longitude': -118.300995},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3515 Wilshire Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90010',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3515 Wilshire Blvd', 'Los Angeles, CA 90010']},
#    'phone': '+12133817411',
#    'display_phone': '(213) 381-7411',
#    'distance': 7105.629961961228},
#   {'id': 'oSqNlNpKImKF69GJ67-rCg',
#    'alias': 'millennium-biltmore-los-angeles-los-angeles-4',
#    'name': 'Millennium Biltmore - Los Angeles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/rfVGM7hPiHBc9-5BNj7P3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/millennium-biltmore-los-angeles-los-angeles-4?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 1308,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.0497299, 'longitude': -118.25389},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '506 S Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['506 S Grand Ave', 'Los Angeles, CA 90071']},
#    'phone': '+12136241011',
#    'display_phone': '(213) 624-1011',
#    'distance': 2682.248205920065},
#   {'id': 'kfaj8WG-vsnj_8kwtpwBaA',
#    'alias': 'the-westin-bonaventure-hotel-and-suites-los-angeles-los-angeles',
#    'name': 'The Westin Bonaventure Hotel & Suites, Los Angeles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/puyMX9K7On4jjZH3cuOINg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-westin-bonaventure-hotel-and-suites-los-angeles-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 1495,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.05256, 'longitude': -118.25601},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '404 S Figueroa St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['404 S Figueroa St', 'Los Angeles, CA 90071']},
#    'phone': '+12136241000',
#    'display_phone': '(213) 624-1000',
#    'distance': 3008.2270767352406},
#   {'id': 'YfirEW27sNpVaSZPRAmKig',
#    'alias': 'the-langham-huntington-pasadena-pasadena-2',
#    'name': 'The Langham Huntington, Pasadena',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M6iI6yzB7Lr1DbX08IMHbw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-langham-huntington-pasadena-pasadena-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 1206,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'resorts', 'title': 'Resorts'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.12031744029123,
#     'longitude': -118.13350349239846},
#    'transactions': [],
#    'price': '$$$$',
#    'location': {'address1': '1401 S Oak Knoll Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Pasadena',
#     'zip_code': '91106',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1401 S Oak Knoll Ave', 'Pasadena, CA 91106']},
#    'phone': '+16265683900',
#    'display_phone': '(626) 568-3900',
#    'distance': 13096.468952890997},
#   {'id': '4wP_NsfWQMzJBSa7PnB-GQ',
#    'alias': 'miyako-hotel-los-angeles',
#    'name': 'Miyako Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rJUuLZswcSE_WrwsjAmA6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/miyako-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 334,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.04966, 'longitude': -118.24032},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '328 E 1st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90012',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['328 E 1st St', 'Los Angeles, CA 90012']},
#    'phone': '+12136172000',
#    'display_phone': '(213) 617-2000',
#    'distance': 1855.5695518538428},
#   {'id': '1kQ42qnTsllIIYMuraxbew',
#    'alias': 'doubletree-by-hilton-hotel-los-angeles-downtown-los-angeles',
#    'name': 'DoubleTree by Hilton Hotel Los Angeles Downtown',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jNWcCaO7ukZYPh6JXUdAtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-los-angeles-downtown-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 585,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.0503518762409,
#     'longitude': -118.24276796543},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '120 S Los Angeles St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90012',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['120 S Los Angeles St', 'Los Angeles, CA 90012']},
#    'phone': '+12136291200',
#    'display_phone': '(213) 629-1200',
#    'distance': 2027.5164728457924},
#   {'id': 'lJL53qxKdR6-cUSiXM_mhw',
#    'alias': 'hotel-normandie-los-angeles',
#    'name': 'Hotel Normandie',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MvhywPoBGAovpF8xdKNNWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-normandie-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 281,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0633173, 'longitude': -118.3005522},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '605 S Normandie Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90005',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['605 S Normandie Ave', 'Los Angeles, CA 90005']},
#    'phone': '+12133888138',
#    'display_phone': '(213) 388-8138',
#    'distance': 7126.48936671523},
#   {'id': 'VID0gqCw40xPO1vqwqUkfw',
#    'alias': 'cara-hotel-los-angeles',
#    'name': 'Cara Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SMq_olKaaRmWo0Z7MEXpVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cara-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 282,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.102806, 'longitude': -118.309047},
#    'transactions': [],
#    'location': {'address1': '1730 N Western Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90027',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1730 N Western Ave', 'Los Angeles, CA 90027']},
#    'phone': '+13236728990',
#    'display_phone': '(323) 672-8990',
#    'distance': 10415.983724787318},
#   {'id': '-PFj_K_yS_IbPKsORGILZw',
#    'alias': 'hotel-figueroa-los-angeles-4',
#    'name': 'Hotel Figueroa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/34QfMtcNR7KdL4zArK86kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-figueroa-los-angeles-4?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 848,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.045564, 'longitude': -118.2640141},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '939 S Figueroa St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['939 S Figueroa St', 'Los Angeles, CA 90015']},
#    'phone': '+12136278971',
#    'display_phone': '(213) 627-8971',
#    'distance': 3244.958650848845},
#   {'id': '-G5KREcTbwx4-sW2FmutnA',
#    'alias': 'downtown-l-a-proper-hotel-los-angeles',
#    'name': 'Downtown LA Proper Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9ouui-hMAd8hTFtoCPGa_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/downtown-l-a-proper-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 65,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0393742, 'longitude': -118.2589819},
#    'transactions': [],
#    'location': {'address1': '1100 S Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1100 S Broadway', 'Los Angeles, CA 90015']},
#    'phone': '+12138061010',
#    'display_phone': '(213) 806-1010',
#    'distance': 2602.756399878386},
#   {'id': 'WNXLZUOs7iZjKaS-6GWa8g',
#    'alias': 'citizenm-dtla-los-angeles',
#    'name': 'CitizenM DTLA',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wjfp4HkfpvFmGY1n6kJB8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citizenm-dtla-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 76,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.04913345932764,
#     'longitude': -118.2483111850467},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '361 S Spring St',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90013',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['361 S Spring St', 'Los Angeles, CA 90013']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2236.6775150613166},
#   {'id': 'U_NGwr6rgGn4GCeYaYgpPw',
#    'alias': 'hotel-per-la-los-angeles',
#    'name': 'Hotel Per La',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vsuRyQD1ZgXfZjR_YgMEQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-per-la-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 42,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.047, 'longitude': -118.25536},
#    'transactions': [],
#    'location': {'address1': '649 S Olive St',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['649 S Olive St', 'Los Angeles, CA 90014']},
#    'phone': '+12133580000',
#    'display_phone': '(213) 358-0000',
#    'distance': 2607.789749937561},
#   {'id': '8yAeldHaddbAnieAlipBsg',
#    'alias': 'freehand-los-angeles-los-angeles-3',
#    'name': 'Freehand Los Angeles',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/99w3fKUQoPUcj7nNZA6LVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/freehand-los-angeles-los-angeles-3?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 393,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'hostels', 'title': 'Hostels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.04471, 'longitude': -118.25646},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '416 West 8th St',
#     'address2': None,
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['416 West 8th St', 'Los Angeles, CA 90014']},
#    'phone': '+12136120021',
#    'display_phone': '(213) 612-0021',
#    'distance': 2570.299066522485},
#   {'id': 'fe41VRFmI1IqCMJElrSmQw',
#    'alias': 'hotel-indigo-los-angeles-downtown-los-angeles-2',
#    'name': 'Hotel Indigo Los Angeles Downtown',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/L82-nK47fCqlAquEuheFHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-indigo-los-angeles-downtown-los-angeles-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 438,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.047415026697244, 'longitude': -118.2646764},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '899 Francisco St',
#     'address2': None,
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90017',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['899 Francisco St', 'Los Angeles, CA 90017']},
#    'phone': '+12136834855',
#    'display_phone': '(213) 683-4855',
#    'distance': 3381.7839349598225},
#   {'id': 'tT2OepXYkeFih_oGfScgGQ',
#    'alias': 'sheraton-grand-los-angeles-los-angeles',
#    'name': 'Sheraton Grand Los Angeles',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zGVZwraAV6kQaBy3hMi6JA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sheraton-grand-los-angeles-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 534,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.04763, 'longitude': -118.25889},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '711 South Hope St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90017',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['711 South Hope St', 'Los Angeles, CA 90017']},
#    'phone': '+12134883500',
#    'display_phone': '(213) 488-3500',
#    'distance': 2864.066683959701},
#   {'id': 'Ft8ussF3uVAiEb8E8SW-VA',
#    'alias': 'residence-inn-by-marriott-los-angeles-l-a-live-los-angeles-2',
#    'name': 'Residence Inn by Marriott Los Angeles L.A. LIVE',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ttl-JxRghaFS7vCeoPT2kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/residence-inn-by-marriott-los-angeles-l-a-live-los-angeles-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 179,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.0459567822529,
#     'longitude': -118.265858888626},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '901 W Olympic Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['901 W Olympic Blvd', 'Los Angeles, CA 90015']},
#    'phone': '+12134439200',
#    'display_phone': '(213) 443-9200',
#    'distance': 3419.1280926615723},
#   {'id': 'tcnGG2bX0RGzB4pJwmxEVA',
#    'alias': 'home2-suites-by-hilton-los-angeles-montebello-montebello-2',
#    'name': 'Home2 Suites by Hilton Los Angeles Montebello',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8Yf2CuN6rUl9rLWgHVS1JQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/home2-suites-by-hilton-los-angeles-montebello-montebello-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 131,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0300137, 'longitude': -118.130191},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '988 Via San Clemente',
#     'address2': '',
#     'address3': None,
#     'city': 'Montebello',
#     'zip_code': '90640',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['988 Via San Clemente', 'Montebello, CA 90640']},
#    'phone': '+13236214111',
#    'display_phone': '(323) 621-4111',
#    'distance': 9330.490069851376},
#   {'id': 'pKTTxkQGNoefJkabS5PKZg',
#    'alias': 'the-wayfarer-downtown-la-tapestry-collection-by-hilton-los-angeles-6',
#    'name': 'The Wayfarer Downtown LA, Tapestry Collection by Hilton',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kdyxB0u-sROHKoknmjYO5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wayfarer-downtown-la-tapestry-collection-by-hilton-los-angeles-6?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 223,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.04718507739884,
#     'longitude': -118.26072701604518},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '813 S Flower St',
#     'address2': None,
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90017',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['813 S Flower St', 'Los Angeles, CA 90017']},
#    'phone': '+12132854400',
#    'display_phone': '(213) 285-4400',
#    'distance': 3042.7454305726374},
#   {'id': 'sRY__do6TgV_-I2D1WmeLw',
#    'alias': 'mama-shelter-los-angeles',
#    'name': 'Mama Shelter',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UOUbhK4_m1BNStkLMauwrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mama-shelter-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 540,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.09961, 'longitude': -118.33135},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '6500 Selma Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90028',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6500 Selma Ave', 'Los Angeles, CA 90028']},
#    'phone': '+13237856666',
#    'display_phone': '(323) 785-6666',
#    'distance': 11696.2151128},
#   {'id': '2yjNMMcjUucNTV42jxFAQA',
#    'alias': 'hilton-checkers-los-angeles-los-angeles',
#    'name': 'Hilton Checkers Los Angeles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7otPBPOYp5-L9P7xHqW6gg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-checkers-los-angeles-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 347,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.0496146, 'longitude': -118.254996},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '535 S Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90071',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['535 S Grand Ave', 'Los Angeles, CA 90071']},
#    'phone': '+12136240000',
#    'display_phone': '(213) 624-0000',
#    'distance': 2736.524004180544},
#   {'id': 'h6MWtlBGODH-iYNEvPmVmA',
#    'alias': 'w-hollywood-hollywood',
#    'name': 'W Hollywood',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xVU7Ee3cteNtz4Z12Fn4ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/w-hollywood-hollywood?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 1030,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.100971, 'longitude': -118.325872},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '6250 Hollywood Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Hollywood',
#     'zip_code': '90028',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6250 Hollywood Blvd', 'Hollywood, CA 90028']},
#    'phone': '+13237981300',
#    'display_phone': '(323) 798-1300',
#    'distance': 11404.116452410526},
#   {'id': 'ltFfc36PvfFaDe1vP-4PWA',
#    'alias': 'hilton-garden-inn-los-angeles-montebello-montebello-3',
#    'name': 'Hilton Garden Inn Los Angeles Montebello',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wcEITyan6XZzqB5aw3Xq6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hilton-garden-inn-los-angeles-montebello-montebello-3?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 197,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.027283, 'longitude': -118.133801},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '801 Via San Clemente',
#     'address2': '',
#     'address3': '',
#     'city': 'Montebello',
#     'zip_code': '90640',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['801 Via San Clemente', 'Montebello, CA 90640']},
#    'phone': '+13237245900',
#    'display_phone': '(323) 724-5900',
#    'distance': 9021.588274150008},
#   {'id': '5lplA1T6vqwKNkYAtyrcbQ',
#    'alias': 'new-seoul-hotel-los-angeles',
#    'name': 'New Seoul Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/91l_OY8rEszcHSAMIxDPoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-seoul-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 47,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.051927138294,
#     'longitude': -118.290242727448},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2666 W Olympic Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90006',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2666 W Olympic Blvd', 'Los Angeles, CA 90006']},
#    'phone': '+12133816262',
#    'display_phone': '(213) 381-6262',
#    'distance': 5756.819520570973},
#   {'id': 'tUvXBv1hUh9MY0ei-LwRwQ',
#    'alias': 'luxe-city-center-hotel-los-angeles',
#    'name': 'Luxe City Center Hotel',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VHm23jJOoBvmbXFKqWe6HQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luxe-city-center-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 386,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.044219, 'longitude': -118.264242},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1020 S Figueroa St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1020 S Figueroa St', 'Los Angeles, CA 90015']},
#    'phone': '+12137481291',
#    'display_phone': '(213) 748-1291',
#    'distance': 3212.6894423658077},
#   {'id': '5OwDyM6_YYcbG_31e_iZAA',
#    'alias': 'kimpton-everly-hotel-los-angeles',
#    'name': 'Kimpton Everly Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-9jIcQQ8DA9ioRNa9teeWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kimpton-everly-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 214,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.10394, 'longitude': -118.3248},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '1800 Argyle Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90028',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1800 Argyle Ave', 'Los Angeles, CA 90028']},
#    'phone': '+12132793532',
#    'display_phone': '(213) 279-3532',
#    'distance': 11566.94576132141},
#   {'id': 'KYFAXpI92pNUzeeSRJSMVA',
#    'alias': 'parkwest-bicycle-casino-bell-gardens-2',
#    'name': 'Parkwest Bicycle Casino ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1MqdklITpcS4ec7UVBTViA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/parkwest-bicycle-casino-bell-gardens-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 402,
#    'categories': [{'alias': 'casinos', 'title': 'Casinos'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.96649008078297,
#     'longitude': -118.16573809999998},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '888 Bicycle Casino Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'Bell Gardens',
#     'zip_code': '90201',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['888 Bicycle Casino Dr', 'Bell Gardens, CA 90201']},
#    'phone': '+15628064646',
#    'display_phone': '(562) 806-4646',
#    'distance': 9705.641455260442},
#   {'id': 'xzkqbPukxN_jA0BH8aSdlw',
#    'alias': 'hampton-inn-and-suites-los-angeles-hollywood-los-angeles-3',
#    'name': 'Hampton Inn & Suites Los Angeles/Hollywood',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UU-Os3-kr598w6kkD-az6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hampton-inn-and-suites-los-angeles-hollywood-los-angeles-3?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 87,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.09178898092595,
#     'longitude': -118.3272616728209},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1133 Vine St',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90038',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1133 Vine St', 'Los Angeles, CA 90038']},
#    'phone': '+13239526900',
#    'display_phone': '(323) 952-6900',
#    'distance': 10877.825084651082},
#   {'id': '7L6NRFv2rPWyE_BNu4-W2A',
#    'alias': 'hollywood-historic-hotel-los-angeles',
#    'name': 'Hollywood Historic Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/dJhWtEdvGfC9Ji7_n8-OTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hollywood-historic-hotel-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 277,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.083341, 'longitude': -118.313062},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5162 Melrose Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90038',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5162 Melrose Ave', 'Los Angeles, CA 90038']},
#    'phone': '+18005151333',
#    'display_phone': '(800) 515-1333',
#    'distance': 9270.108045195206},
#   {'id': 'NjGkRYbc6baHhLvSuJeYhg',
#    'alias': 'o-hotel-and-spa-los-angeles',
#    'name': 'O Hotel & Spa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4yojIugOnVIiFqveebLphg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/o-hotel-and-spa-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 286,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 34.046979, 'longitude': -118.2608},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '819 S Flower St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90017',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['819 S Flower St', 'Los Angeles, CA 90017']},
#    'phone': '+12136239904',
#    'display_phone': '(213) 623-9904',
#    'distance': 3038.464350253665},
#   {'id': 'E-RKG6U6e6TI6yggeJ55Kw',
#    'alias': 'doubletree-by-hilton-hotel-los-angeles-commerce-commerce',
#    'name': 'DoubleTree by Hilton Hotel Los Angeles - Commerce',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hCAXoc-YBLhXG3KZYKNWLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/doubletree-by-hilton-hotel-los-angeles-commerce-commerce?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 259,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.00376, 'longitude': -118.150533288717},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '5757 Telegraph Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Commerce',
#     'zip_code': '90040',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5757 Telegraph Rd', 'Commerce, CA 90040']},
#    'phone': '+13238878100',
#    'display_phone': '(323) 887-8100',
#    'distance': 8203.34766177633},
#   {'id': '5udpvtU5XGiQtWjUHfXEIA',
#    'alias': 'gold-diggers-los-angeles-4',
#    'name': 'Gold-Diggers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/f8B_e6QOlbPrYZLi1wASew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gold-diggers-los-angeles-4?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 69,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'recording_studios', 'title': 'Recording & Rehearsal Studios'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0906151, 'longitude': -118.3126463},
#    'transactions': [],
#    'location': {'address1': '5632 Santa Monica Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90038',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5632 Santa Monica Blvd', 'Los Angeles, CA 90038']},
#    'phone': '+13235460300',
#    'display_phone': '(323) 546-0300',
#    'distance': 9722.745721527894},
#   {'id': 'CDdEFf1YNb3edzHQk5inAQ',
#    'alias': 'villa-delle-stelle-hollywood',
#    'name': 'Villa Delle Stelle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8sBwt-MvZ7--tXvEbrpq8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/villa-delle-stelle-hollywood?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 60,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.0991419043124,
#     'longitude': -118.321776836923},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6087 Harold Way',
#     'address2': '',
#     'address3': '',
#     'city': 'Hollywood',
#     'zip_code': '90028',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6087 Harold Way', 'Hollywood, CA 90028']},
#    'phone': '+13238768100',
#    'display_phone': '(323) 876-8100',
#    'distance': 10985.118853754491},
#   {'id': 'HLSSW8FZXWd3X50bh6dJww',
#    'alias': 'aventura-hotel-los-angeles-2',
#    'name': 'Aventura Hotel',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5KWuCZEsApcx0Vo-ADvbiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aventura-hotel-los-angeles-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 230,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.05216, 'longitude': -118.29757},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1020 Fedora St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90006',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1020 Fedora St', 'Los Angeles, CA 90006']},
#    'phone': '+12133861020',
#    'display_phone': '(213) 386-1020',
#    'distance': 6395.5456857222325},
#   {'id': '2DyP8qgeT3uI6VIjTVH-Ww',
#    'alias': 'sentral-dtla-at-732-spring-street-los-angeles',
#    'name': 'Sentral DTLA at 732 Spring Street',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IvIX_zowwoArIROd7RgBYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sentral-dtla-at-732-spring-street-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 51,
#    'categories': [{'alias': 'apartments', 'title': 'Apartments'},
#     {'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.04361, 'longitude': -118.2529},
#    'transactions': [],
#    'location': {'address1': '732 S Spring St',
#     'address2': '',
#     'address3': None,
#     'city': 'Los Angeles',
#     'zip_code': '90014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['732 S Spring St', 'Los Angeles, CA 90014']},
#    'phone': '+13234053039',
#    'display_phone': '(323) 405-3039',
#    'distance': 2208.3612352573787},
#   {'id': '7KitXLqfHXuSqcXdkUstFA',
#    'alias': 'courtyard-by-marriott-los-angeles-l-a-live-los-angeles-2',
#    'name': 'Courtyard by Marriott Los Angeles L.A. LIVE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0xK8AjL2vmNxJHWP2c-Itg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-by-marriott-los-angeles-l-a-live-los-angeles-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 129,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.04599780845, 'longitude': -118.265808046627},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '901 W Olympic Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90015',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['901 W Olympic Blvd', 'Los Angeles, CA 90015']},
#    'phone': '+12134439200',
#    'display_phone': '(213) 443-9200',
#    'distance': 3416.4223871413187},
#   {'id': 'mIiEOQP28BXAuWTgoQcQrA',
#    'alias': 'hotel-covell-los-angeles',
#    'name': 'Hotel Covell',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rKG1Ir3GFLnNqplDi75j1Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hotel-covell-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 20,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.0998023, 'longitude': -118.2899435},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '4626 Hollywood Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90027',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4626 Hollywood Blvd', 'Los Angeles, CA 90027']},
#    'phone': '+13236604300',
#    'display_phone': '(323) 660-4300',
#    'distance': 9042.211660022724},
#   {'id': 'bqK7L9K2qoME5gfWh_lZuQ',
#    'alias': 'level-los-angeles-downtown-south-olive-los-angeles',
#    'name': 'Level Los Angeles - Downtown South Olive',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/52Gic9GY2IlD4vM59zHKpw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/level-los-angeles-downtown-south-olive-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 232,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'apartments', 'title': 'Apartments'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 34.044064, 'longitude': -118.257637},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '888 S Olive St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['888 S Olive St', 'Los Angeles, CA 90014']},
#    'phone': '+12138738400',
#    'display_phone': '(213) 873-8400',
#    'distance': 2638.017921884886},
#   {'id': 'eee_2iYbnXuYzDowISDoFw',
#    'alias': 'greentree-inn-alhambra-alhambra-2',
#    'name': 'GreenTree Inn - Alhambra',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qesD2xg6J-xpk4YjMt5zJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greentree-inn-alhambra-alhambra-2?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 72,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.0953835059623,
#     'longitude': -118.150723725557},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2499 W Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Alhambra',
#     'zip_code': '91801',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2499 W Main St', 'Alhambra, CA 91801']},
#    'phone': '+16262848498',
#    'display_phone': '(626) 284-8498',
#    'distance': 10022.1300829999},
#   {'id': 'p9VOCmzFu4qiywsNimzr1g',
#    'alias': 'courtyard-by-marriott-monterey-park',
#    'name': 'Courtyard By Marriott',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2gg9XMm0V8toTlleDf6sgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/courtyard-by-marriott-monterey-park?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 81,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.06853464616973,
#     'longitude': -118.13463306279236},
#    'transactions': [],
#    'location': {'address1': '555 N Atlantic Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Monterey Park',
#     'zip_code': '91754',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['555 N Atlantic Blvd', 'Monterey Park, CA 91754']},
#    'phone': '+16266564056',
#    'display_phone': '(626) 656-4056',
#    'distance': 9661.83604505942},
#   {'id': 'Z-YfxL8_ECPm-E-OLbGmRQ',
#    'alias': 'best-western-plus-dragon-gate-inn-los-angeles',
#    'name': 'Best Western Plus Dragon Gate Inn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yT3xZVXr19ndCcy4Jl7AWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/best-western-plus-dragon-gate-inn-los-angeles?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 147,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 34.063266, 'longitude': -118.238944},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '818 N Hill St',
#     'address2': '',
#     'address3': '',
#     'city': 'Los Angeles',
#     'zip_code': '90012',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['818 N Hill St', 'Los Angeles, CA 90012']},
#    'phone': '+12136173077',
#    'display_phone': '(213) 617-3077',
#    'distance': 3243.0714874253918},
#   {'id': '67t9_gKJhA7CkytmUR6FzQ',
#    'alias': 'dunes-inn-sunset-hollywood',
#    'name': 'Dunes Inn Sunset',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WNMz0VdTYVfpvXzj-Aue9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dunes-inn-sunset-hollywood?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 69,
#    'categories': [{'alias': 'hotels', 'title': 'Hotels'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 34.09846, 'longitude': -118.3124},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5625 W Sunset Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Hollywood',
#     'zip_code': '90028',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5625 W Sunset Blvd', 'Hollywood, CA 90028']},
#    'phone': '+13234675171',
#    'display_phone': '(323) 467-5171',
#    'distance': 10277.052125294455},
#   {'id': 'RsGwD5cK5J2AyNv3SUTvdw',
#    'alias': 'the-commerce-casino-and-hotel-commerce-3',
#    'name': 'The Commerce Casino & Hotel',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6afX3pFyG0iphtlY-CykBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-commerce-casino-and-hotel-commerce-3?adjust_creative=d6_d6L4oKrfbGmQkOErdsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d6_d6L4oKrfbGmQkOErdsg',
#    'review_count': 457,
#    'categories': [{'alias': 'casinos', 'title': 'Casinos'},
#     {'alias': 'hotels', 'title': 'Hotels'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 33.998901, 'longitude': -118.145188},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6131 E Telegraph Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Commerce',
#     'zip_code': '90040',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['6131 E Telegraph Rd', 'Commerce, CA 90040']},
#    'phone': '+13237212100',
#    'display_phone': '(323) 721-2100',
#    'distance': 8882.29565303991}],
#  'total': 302,
#  'region': {'center': {'longitude': -118.23128, 'latitude': 34.0348}}}

# %%
results_yelp_bars = pd.json_normalize(bars['businesses'])
results_yelp_bars.head()
# Out:
#                         id                                              alias  \
# 0   xJToH_Gy8RSKWqUPVUjwLw                  the-hoxton-downtown-los-angeles-6
# 1   u6wFTRE9RUY_LGNnIDbrzQ  omni-los-angeles-hotel-at-california-plaza-los...
# 2   1fGCTpM3zrcAgytrZA4mPQ        los-angeles-athletic-club-hotel-los-angeles
# 3   Nh3L9PtJZTSGhfeAxKO3Gg       jw-marriott-los-angeles-l-a-live-los-angeles
# 4   kvhmfXZ-JSkUUlsod_34OA         ace-hotel-downtown-los-angeles-los-angeles
# 5   1PSkXp8N6-cczfIBijTgNA  intercontinental-los-angeles-downtown-los-ange...
# 6   gO4UMDCi7g0r_oiq_cUq1g                     conrad-los-angeles-los-angeles
# 7   hMoFC3fmCEN-bRAB_c_Ujw         the-ritz-carlton-los-angeles-los-angeles-7
# 8   Wh5ix84uh6MO5Rs1kI02gw                            the-line-la-los-angeles
# 9   oSqNlNpKImKF69GJ67-rCg      millennium-biltmore-los-angeles-los-angeles-4
# 10  kfaj8WG-vsnj_8kwtpwBaA  the-westin-bonaventure-hotel-and-suites-los-an...
# 11  YfirEW27sNpVaSZPRAmKig         the-langham-huntington-pasadena-pasadena-2
# 12  4wP_NsfWQMzJBSa7PnB-GQ                           miyako-hotel-los-angeles
# 13  1kQ42qnTsllIIYMuraxbew  doubletree-by-hilton-hotel-los-angeles-downtow...
# 14  lJL53qxKdR6-cUSiXM_mhw                        hotel-normandie-los-angeles
# 15  VID0gqCw40xPO1vqwqUkfw                             cara-hotel-los-angeles
# 16  -PFj_K_yS_IbPKsORGILZw                       hotel-figueroa-los-angeles-4
#
#                                            categories  rating transactions  \
# 0   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.5           []
# 1   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.0           []
# 2   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.0           []
# 3   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.0           []
# 4            [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 5            [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 6            [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 7   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.0           []
# 8   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.0           []
# 9   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.0           []
# 10  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.0           []
# 11  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.5           []
# 12           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 13           [{'alias': 'hotels', 'title': 'Hotels'}]     3.0           []
# 14           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 15           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 16           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 17  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     4.0           []
# 18           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 19  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.5           []
# 20  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.0           []
# 21  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.5           []
# 22  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.0           []
# 23           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 24           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 25           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 26           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 27           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 28           [{'alias': 'hotels', 'title': 'Hotels'}]     3.0           []
# 29           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 30           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 31           [{'alias': 'hotels', 'title': 'Hotels'}]     3.0           []
# 32  [{'alias': 'venues', 'title': 'Venues & Event ...     3.5           []
# 33  [{'alias': 'casinos', 'title': 'Casinos'}, {'a...     3.5           []
# 34           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 35           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 36           [{'alias': 'hotels', 'title': 'Hotels'}]     3.0           []
# 37           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 38  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.0           []
# 39           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 40           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 41  [{'alias': 'apartments', 'title': 'Apartments'...     3.5           []
# 42           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 43  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     5.0           []
# 44  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     2.5           []
# 45           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 46  [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...     3.5           []
# 47           [{'alias': 'hotels', 'title': 'Hotels'}]     3.5           []
# 48           [{'alias': 'hotels', 'title': 'Hotels'}]     4.0           []
# 49  [{'alias': 'casinos', 'title': 'Casinos'}, {'a...     2.5           []
#
#     ... coordinates.latitude coordinates.longitude       location.address1  \
# 0   ...            34.039794           -118.258561         1060 S Broadway
# 1   ...            34.052599           -118.250504          251 S Olive St
# 2   ...            34.046640           -118.254980            431 W 7th St
# 3   ...            34.045238           -118.266470   900 West Olympic Blvd
# 4   ...            34.041741           -118.256794          929 S Broadway
# 5   ...            34.050142           -118.260300       900 Wilshire Blvd
# 6   ...            34.055360           -118.248790    100 South Grand Ave.
# 7   ...            34.045263           -118.266620      900 W Olympic Blvd
# 8   ...            34.062130           -118.300995      3515 Wilshire Blvd
# 9   ...            34.049730           -118.253890         506 S Grand Ave
# 10  ...            34.052560           -118.256010       404 S Figueroa St
# 11  ...            34.120317           -118.133503    1401 S Oak Knoll Ave
# 12  ...            34.049660           -118.240320            328 E 1st St
# 13  ...            34.050352           -118.242768    120 S Los Angeles St
# 14  ...            34.063317           -118.300552     605 S Normandie Ave
# 15  ...            34.102806           -118.309047      1730 N Western Ave
# 16  ...            34.045564           -118.264014       939 S Figueroa St
# 17  ...            34.039374           -118.258982         1100 S Broadway
# 18  ...            34.049133           -118.248311         361 S Spring St
# 19  ...            34.047000           -118.255360          649 S Olive St
# 20  ...            34.044710           -118.256460         416 West 8th St
# 21  ...            34.047415           -118.264676        899 Francisco St
# 22  ...            34.047630           -118.258890       711 South Hope St
# 23  ...            34.045957           -118.265859      901 W Olympic Blvd
# 24  ...            34.030014           -118.130191    988 Via San Clemente
# 25  ...            34.047185           -118.260727         813 S Flower St
# 26  ...            34.099610           -118.331350          6500 Selma Ave
# 27  ...            34.049615           -118.254996         535 S Grand Ave
# 28  ...            34.100971           -118.325872     6250 Hollywood Blvd
# 29  ...            34.027283           -118.133801    801 Via San Clemente
# 30  ...            34.051927           -118.290243     2666 W Olympic Blvd
# 31  ...            34.044219           -118.264242      1020 S Figueroa St
# 32  ...            34.103940           -118.324800         1800 Argyle Ave
# 33  ...            33.966490           -118.165738   888 Bicycle Casino Dr
# 34  ...            34.091789           -118.327262            1133 Vine St
# 35  ...            34.083341           -118.313062        5162 Melrose Ave
# 36  ...            34.046979           -118.260800         819 S Flower St
# 37  ...            34.003760           -118.150533       5757 Telegraph Rd
# 38  ...            34.090615           -118.312646  5632 Santa Monica Blvd
# 39  ...            34.099142           -118.321777         6087 Harold Way
# 40  ...            34.052160           -118.297570          1020 Fedora St
# 41  ...            34.043610           -118.252900         732 S Spring St
# 42  ...            34.045998           -118.265808      901 W Olympic Blvd
# 43  ...            34.099802           -118.289944     4626 Hollywood Blvd
# 44  ...            34.044064           -118.257637          888 S Olive St
# 45  ...            34.095384           -118.150724          2499 W Main St
# 46  ...            34.068535           -118.134633     555 N Atlantic Blvd
# 47  ...            34.063266           -118.238944           818 N Hill St
# 48  ...            34.098460           -118.312400      5625 W Sunset Blvd
# 49  ...            33.998901           -118.145188     6131 E Telegraph Rd
#
#     location.address2  location.address3  location.city location.zip_code  \
# 0                                   None    Los Angeles             90015
# 1                                           Los Angeles             90012
# 2                None                       Los Angeles             90014
# 3                                           Los Angeles             90015
# 4                                           Los Angeles             90015
# 5                                   None    Los Angeles             90017
# 6                None               None    Los Angeles             90012
# 7                                           Los Angeles             90015
# 8                                           Los Angeles             90010
# 9                                           Los Angeles             90071
# 10                                          Los Angeles             90071
# 11                                             Pasadena             91106
# 12                                          Los Angeles             90012
# 13                                          Los Angeles             90012
# 14                                          Los Angeles             90005
# 15                                  None    Los Angeles             90027
# 16                                          Los Angeles             90015
# 17               None                       Los Angeles             90015
# 18                                  None    Los Angeles             90013
# 19                                  None    Los Angeles             90014
# 20               None               None    Los Angeles             90014
# 21               None               None    Los Angeles             90017
# 22                                          Los Angeles             90017
# 23               None               None    Los Angeles             90015
# 24                                  None     Montebello             90640
# 25               None               None    Los Angeles             90017
# 26               None                       Los Angeles             90028
# 27                                          Los Angeles             90071
# 28                                            Hollywood             90028
# 29                                           Montebello             90640
# 30                                          Los Angeles             90006
# 31                                          Los Angeles             90015
# 32               None               None    Los Angeles             90028
# 33                                         Bell Gardens             90201
# 34                                  None    Los Angeles             90038
# 35                                          Los Angeles             90038
# 36                                          Los Angeles             90017
# 37                                             Commerce             90040
# 38                                  None    Los Angeles             90038
# 39                                            Hollywood             90028
# 40                                          Los Angeles             90006
# 41                                  None    Los Angeles             90014
# 42                                          Los Angeles             90015
# 43                                          Los Angeles             90027
# 44                                          Los Angeles             90014
# 45                                  None       Alhambra             91801
# 46                                  None  Monterey Park             91754
# 47                                          Los Angeles             90012
# 48                                            Hollywood             90028
# 49                                             Commerce             90040
#
#    location.country location.state  \
# 0                US             CA
# 1                US             CA
# 2                US             CA
# 3                US             CA
# 4                US             CA
# 5                US             CA
# 6                US             CA
# 7                US             CA
# 8                US             CA
# 9                US             CA
# 10               US             CA
# 11               US             CA
# 12               US             CA
# 13               US             CA
# 14               US             CA
# 15               US             CA
# 16               US             CA
# 17               US             CA
# 18               US             CA
# 19               US             CA
# 20               US             CA
# 21               US             CA
# 22               US             CA
# 23               US             CA
# 24               US             CA
# 25               US             CA
# 26               US             CA
# 27               US             CA
# 28               US             CA
# 29               US             CA
# 30               US             CA
# 31               US             CA
# 32               US             CA
# 33               US             CA
# 34               US             CA
# 35               US             CA
# 47           [818 N Hill St, Los Angeles, CA 90012]
# 48        [5625 W Sunset Blvd, Hollywood, CA 90028]
# 49        [6131 E Telegraph Rd, Commerce, CA 90040]
#
# [50 rows x 24 columns]

# %% [markdown]
# ### Repeat the functions created to loop through the Foursquare results for YELP

# %%
#def category_count_yelp(category):
    """
    Loop through the stations_df_fs dataframe and return a list of counts of the number of items returned in the get_venues_fs function that corresponds with the input category
    
    Args:
        category (integer): the category integer of what POI we are searching for

    Returns:
        response: count_of_category: a list of the number of POI's which match the category integer from the get_venues_fs function
    """
    count_of_category = []

    for row in stations_df_fs.itertuples(index=False): 
        
        latitude = row[8] # store the latitude of each station in a variable
        longitude = row[9] # store the longitude of each station in a variable
        
        venue_results = get_venues_yelp(latitude, longitude, 1000, category) # call the get_venues_fs function for each station 
        normalized_results = pd.json_normalize(venue_results['businesses']) # store and normalize the results
        
        count_of_results = len(normalized_results) # count the number of rows in the normalized results
        count_of_category.append(count_of_results) # append the count to the empty list
    
    return count_of_category

# %% [markdown]
# ### After calling this function on all three categories, the results showed that the return limit of 50 results was reached for each station and therefore, the analysis will focus the API calls on the other YELP functions.

# %%
def average_rating_yelp(category):
    """
    Loop through the stations_df_fs dataframe and return the calculated average ratings from the items returned in the get_venues_yelp function that corresponds with the input category and append that value to a list
    
    Args:
        category (string): the category string of businesses we are searching for. For multiple categories, input a comma-separated string list "hotel,bars"

    Returns:
        response: average_category_rating: a list of the average ranking of businesses which match the category integer from the get_venues_yelp function
    """
    average_category_rating = []

    for row in stations_df_fs.itertuples(index=False): 
        
        latitude = row[8] # store the latitude of each station in a variable
        longitude = row[9] # store the longitude of each station in a variable
        
        venue_results = get_venues_yelp(latitude, longitude, 1000, category) # call the get_venues_fs function for each station 
        normalized_results = pd.json_normalize(venue_results['businesses']) # store and normalize the results
        
        # Check if the 'rating' column exists in the normalized results
        if 'rating' in normalized_results.columns:
            average_rating = normalized_results['rating'].mean()
            average_category_rating.append(average_rating)
        else:
            # Case when the 'rating' column is missing
            average_category_rating.append(0)
        
    return average_category_rating

# %%
#def average_reviews_yelp(category):
    """
    Loop through the stations_df_fs dataframe and return the calculated average number of reviews from the items returned in the get_venues_yelp function that corresponds with the input category and append that value to a list
    
    Args:
        category (string): the category string of businesses we are searching for ('transport'). For multiple categories, input a comma-separated string list ("hotel,bars")

    Returns:
        response: average_count_reviews: a list of the average number of reviews for the businesses which match the category integer from the get_venues_yelp function
    """
    average_count_reviews = []

    for row in stations_df_fs.itertuples(index=False): 
        
        latitude = row[8] # store the latitude of each station in a variable
        longitude = row[9] # store the longitude of each station in a variable
        
        venue_results = get_venues_yelp(latitude, longitude, 1000, category) # call the get_venues_fs function for each station 
        normalized_results = pd.json_normalize(venue_results['businesses']) # store and normalize the results
        
        # Check if the 'review_count' column exists in the normalized results
        if 'review_count' in normalized_results.columns:
            average_reviews = normalized_results['review_count'].mean()
            average_count_reviews.append(average_reviews)
        else:
            # Case when the 'review_count' column is missing
            average_count_reviews.append(0)
        
    return average_count_reviews

# %%
# average_num_yelp_reviews_bar = average_reviews_yelp('bars')

# %% [markdown]
# ### Put your parsed results into a DataFrame

# %%
# call the function on the bar category
average_yelp_rating_bars = average_rating_yelp('bars')

# %%
# append the results of the function above to the dataframe as a column for analysis
stations_df_fs['average_yelp_rating_bar'] = average_rating_yelp_bars

# %% [markdown]
# #### API limit reached for day, save dataframe and resume when API limit resets

# %%
stations_df_fs_yelp = stations_df_fs.to_csv('stations_df_fs_yelp.csv')

# %% [markdown]
# #### API limit reset, read in saved dataframe and call YELP functions for remaining categories

# %%
#read in the csv
stations_df_fs_yelp = pd.read_csv('stations_df_fs.csv')

# %%
# test the function for hotels category
average_yelp_rating_hotels = average_rating_yelp('hotels')

# %%
# call the function on transport category
average_yelp_rating_transport = average_rating_yelp('transport')

# %%
# append the results of the hotel function to the dataframe
stations_df_fs_yelp['average_yelp_rating_hotels'] = average_yelp_rating_hotels

# %%
# append the results of the hotel function to the dataframe
stations_df_fs_yelp['average_yelp_rating_transport'] = average_yelp_rating_transport

# %%
# save the dataframe to a .csv
stations_df_fs_yelp_1 = stations_df_fs_yelp.to_csv('stations_df_fs_yelp_1.csv')

# %% [markdown]
# # Comparing Results

# %% [markdown]
# ## Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# ### Foursquare
#
# #### Pros:
# In the context of this analysis, I believe that the popularity metric, which only Foursquare provides, is very powerful. When factoring in bike rentals, this mode of transportation is closer to walking than it is to vehicular travel, and therefore this shows a correlation. I also believe that because the metric is only for the last six months, this allows the metric to be more fluid and accurate. For example, imagine a bar opened 5 years ago and as of today, the bar has a 9/10 rating on Foursquare. However, under closer scrutiny, most good reviews came more than three years ago, and the average rating in the last two years is lower than before. This allows us to compare the normalized rating and popularity values later to see how well they compare.
# #### Cons:
# Not having a 'reviews' column to show the number of reviews that went into calculating the 'rating' column makes the 'rating' a black box; there could be only one review for a POI.
#
# ### YELP
#
# #### Pros:
# The reviews column allows for filtering out results that don't meet a specified threshold if required. Additionally, there are more businesses on YELP vs. Foursquare, which better represents the real world.
#
# #### Cons:
# The limitations of the YELP API are much more restrictive and prevent tuning of the request with the 500 API calls per day limit. The ability to call the Foursquare API with fewer restrictions is very helpful to iteratively build functions by testing each step. Additionally, the rating column for YELP is on a scale from 0 - 5 compared to the Foursquare scale of 0 - 10 which allows for better precision.
#
# Considering the above, I believe the Foursquare API provided me with more complete data.

# %% [markdown]
# ## Get the top 10 restaurants according to their rating

# %%
def get_restaurants_fs(latitude, longitude, radius, categories):
    """
    Get restaurants from foursquare with a specified place type and coordinates.
    Args:
        latitude (float): latitude for query (must be combined with longitude)
        longitude (float): longitude for query (must be combined with latitude)
        api_key (str): foursquare API to use for query
        categories (str) : Foursquare-recognized place type. If not passed no place_type will be specified. Separate ids with commas
    
    Returns:
        response: response object from the requests library.
    """
    url = "https://api.foursquare.com/v3/places/search"
    
    params = {"categories": categories, # below, we will search for three different category types
              "radius":radius,
              "ll": f"{latitude},{longitude}",
              "limit":50, # this is the upper limit
              "fields": "fsq_id,name,rating"  
            }
    # Create a dictionary for headers
    headers = {"Accept": "application/json"}
    # Add key with our API KEY
    headers['Authorization'] = FOURSQUARE_KEY 
    res = requests.get(url, params=params, headers=headers)
    foursquare_data = res.json()
    return foursquare_data

# %%
# using the above function, loop through each station, searching for restaurants, append the results to an empty list, then concatenate to the new dataframe
restaurants = pd.DataFrame() # empty dataframe that will have values concatenated to it
list_of_restaurants = [] # empty list for appending results

for row in stations_df.itertuples(index=False):
    latitude = row[8]
    longitude = row[9]
            
    venue_results = get_restaurants_fs(latitude, longitude, 1000, FOURSQUARE_KEY, 13065)
    normalized_results = pd.json_normalize(venue_results['results'])
    list_of_restaurants.append(normalized_results)

restaurants = pd.concat(list_of_restaurants)

# %%
# Fill the NaN values for restaurants with zeros
restaurants = restaurants.fillna(0)
restaurants
# Out:
#                       fsq_id                    name  rating
# 0   60c184c9528f822158a147e8             Afuri Ramen     8.9
# 1   55fccaa5498ec525f32b644d       Everson Rocye Bar     9.1
# 2   4a15b070f964a520b9781fe3           Tony's Saloon     8.6
# 3   4e0e69c445ddc2c6d1780ab2              Pizzanista     8.4
# 4   5b549f2ec97f28002cb31a5f         Guerrilla Tacos     8.5
# ..                       ...                     ...     ...
# 37  63d4b6beea0fa64ea1f18ef1   Mun Korean Steakhouse     0.0
# 38  4c9e3729d3c2b60cb8f7c8bc            La Poblanita     0.0
# 39  62bf97634432bf416e57b6ba  Kunnai Thai Restaurant     0.0
# 40  7c75265c14f0448ae6e60e30      Mariscos Michoacan     0.0
# 41  1a044c093087480a0956c6a7            Brass Monkey     0.0
#
# [9090 rows x 3 columns]

# %%
# check for duplicate values
restaurants.duplicated().sum()
# Out:
# 6950

# %%
# the majority of the restaurants are duplicates, drop from the analysis
clean_restaurants = restaurants.drop_duplicates(subset=['fsq_id'], keep='first')
# remove the fsq_id column
clean_restaurants = clean_restaurants.drop(['fsq_id'],axis=1)
clean_restaurants
# Out:
#                      name  rating
# 0             Afuri Ramen     8.9
# 1       Everson Rocye Bar     9.1
# 2           Tony's Saloon     8.6
# 3              Pizzanista     8.4
# 4         Guerrilla Tacos     8.5
# ..                    ...     ...
# 33         Citizen Sprout     0.0
# 34                 Citrin     0.0
# 35  Tiato Kitchen & Venue     0.0
# 36              Cafe Lucy     0.0
# 37        Jack In The Box     5.3
#
# [2140 rows x 2 columns]

# %%
# sort the values by 'rating' and return the top 10
top_10_restaurants = clean_restaurants.sort_values('rating', ascending=False).head(10)

# %% [markdown]
# #### The top 10 restaurants from Foursquare results within 1000m of all city bik.es stations are:

# %%
top_10_restaurants
# Out:
#                                  name  rating
# 7                        Salt & Straw     9.4
# 8            Saffron & Rose Ice Cream     9.3
# 11                           Guisados     9.3
# 2   Firestone Walker - The Propagator     9.3
# 11               Superba Food + Bread     9.3
# 0               Porto's Bakery & Cafe     9.3
# 9                               Bavel     9.3
# 35                             Cobi's     9.3
# 24           Walt Disney Concert Hall     9.3
# 7                        Hatchet Hall     9.2
